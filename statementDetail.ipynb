# %%
from statement import *

# %%
st=StatementManage('2022-11-08',5)

# %%
st.nYearDataFromSql
# Out:
#        index        date stock_id                               type  \
# 26387  26387  2017-09-30     9962  TotalNonoperatingIncomeAndExpense
# 8788    8788  2017-09-30     2855              IncomeBeforeIncomeTax
# 8789    8789  2017-09-30     2855     IncomeFromContinuingOperations
# 8790    8790  2017-09-30     2855                          NetIncome
# 8791    8791  2017-09-30     2855            NoncontrollingInterests
# ...      ...         ...      ...                                ...
# 22992  22992  2022-06-30     6179                  OperatingExpenses
# 22993  22993  2022-06-30     6179                    OperatingIncome
# 22994  22994  2022-06-30     6179  TotalNonoperatingIncomeAndExpense
# 22980  22980  2022-06-30     6177  TotalNonoperatingIncomeAndExpense
# 0          0  2022-06-30   000104                                TAX
#
#              value     origin_name
# 26387    2863000.0        營業外收入及支出
# 8788   708767000.0        稅前淨利(淨損)
# ...

# %%
columns1=st.nYearDataFromSql.pivot_table(columns=['type','origin_name'])

# %%
for item in columns1:
    print(item)
# Out:
# ('-', '合併前非屬共同控制股權損益')
# ('-', '合併前非屬共同控制股權綜合損益淨額')
# ('-', '淨利（損）歸屬於共同控制下前手權益')
# ('-', '淨利（淨損）歸屬於共同控制下前手權益')
# ('-', '綜合損益總額歸屬於共同控制下前手權益')
# ('BadDebtExpenseGuaranteeLiabilityProvisions', '呆帳費用及保證責任準備提存')
# ('BadDebtExpenseGuaranteeLiabilityProvisions', '呆帳費用及保證責任準備提存(各項提存)')
# ('BadDebts', '呆帳費用、承諾及保證責任準備提存')
# ('CostOfGoodsSold', '支出')
# ('CostOfGoodsSold', '營業成本')
# ('EPS', '基本每股盈餘（元）')
# ('EquityAttributableToOwnersOfParent', '淨利（損）歸屬於母公司業主')
# ('EquityAttributableToOwnersOfParent', '淨利（淨損）歸屬於母公司業主')
# ('EquityAttributableToOwnersOfParent', '綜合損益總額歸屬於母公司業主')
# ('Expense', '支出及費用')
# ('GainsOnChangesInFairValueLessCosts2SellOfBiologicalAssetsForCurrentPeriod', '生物資產當期公允價值減出售成本之變動利益（損失）')
# ('GainsOnInitialRecognitionOfBiologicalAssetsForCurrentPeriod', '原始認列生物資產及農產品之利益（損失）')
# ('GrossProfit', '營業毛利（毛損）')
# ('GrossProfit', '營業毛利（毛損）淨額')
# ('Income', '收益')
# ('IncomeAfterTax', '本期稅後淨利（淨損）')
# ('IncomeAfterTaxes', '本期淨利（淨損）')
# ('IncomeBeforeIncomeTax', '稅前淨利(淨損)')
# ...

# %%
columns2=st.nYearDataFromSql.pivot_table(columns=['type'])

# %%
for item in columns2:
    print(item)
# Out:
# -
# BadDebtExpenseGuaranteeLiabilityProvisions
# BadDebts
# CostOfGoodsSold
# EPS
# EquityAttributableToOwnersOfParent
# Expense
# GainsOnChangesInFairValueLessCosts2SellOfBiologicalAssetsForCurrentPeriod
# GainsOnInitialRecognitionOfBiologicalAssetsForCurrentPeriod
# GrossProfit
# Income
# IncomeAfterTax
# IncomeAfterTaxes
# IncomeBeforeIncomeTax
# IncomeBeforeTaxFromContinuingOperations
# IncomeFromContinuingOperations
# IncomeLossFromDiscontinuedOperation
# NetChangeInProvisionsForInsuranceLiabilities
# NetIncome
# NetInterestIncome
# NetNonInterestIncome
# NoncontrollingInterests
# OTHNOE
# OperatingExpenses
# OperatingIncome
# OtherComprehensiveIncome
# OtherComprehensiveIncomeAfterTax
# OtherComprehensiveIncomeAfterTaxThePeriod
# PreTaxIncome
# RealizedGain
# Revenue
# TAX
# TotalConsolidatedProfitForThePeriod
# TotalConsolidatedProfitForThePeriodAfterTax
# TotalNonbusinessIncome
# TotalNonoperatingIncomeAndExpense
# UnrealizedGain
# 呆帳費用及保證責任準備提存（各項提存）
# 所得稅利益（費用）

# %%
typeData=st.getType("Revenue")
typeData
# Out:
# stock_id            1101          1102         1103          1104  \
# date
# 2017-09-30  2.305830e+10  1.653830e+10  506346000.0  1.128090e+09
# 2017-12-31  2.935970e+10  1.955020e+10  530377000.0  1.117520e+09
# 2018-03-31  2.417920e+10  1.657390e+10  471257000.0  1.166100e+09
# 2018-06-30  3.332100e+10  2.243520e+10  529670000.0  1.148760e+09
# 2018-09-30  3.215710e+10  2.189900e+10  494280000.0  1.121590e+09
# 2018-12-31  3.493720e+10  2.183290e+10  597199000.0  1.344550e+09
# 2019-03-31  2.535630e+10  1.938570e+10  452376000.0  1.187300e+09
# 2019-06-30  3.136720e+10  2.441990e+10  438033000.0  1.194170e+09
# 2019-09-30  3.083840e+10  2.240130e+10  472584000.0  1.169890e+09
# 2019-12-31  3.522110e+10  2.314080e+10  521009000.0  1.454380e+09
# 2020-03-31  2.197620e+10  1.313888e+10  495334000.0  1.253758e+09
# 2020-06-30  3.046363e+10  2.068921e+10  496985000.0  1.337873e+09
# 2020-09-30  2.980866e+10  2.073608e+10  489170000.0  1.294920e+09
# ...

# %%
for item in typeData.columns:
    print(item)
# Out:
# 1101
# 1102
# 1103
# 1104
# 1108
# 1109
# 1110
# 1111
# 1201
# 1203
# 1210
# 1213
# 1215
# 1216
# 1217
# 1218
# 1219
# 1220
# 1225
# 1227
# 1229
# 1231
# 1232
# 1233
# 1234
# 1235
# 1236
# 1237
# 1240
# 1242
# 1246
# 1256
# 1258
# 1259
# 1260
# 1264
# 1267
# 1268
# 1269
# 1271
# 1293
# 1294
# 1301
# 1303
# 1304
# 1305
# 1307
# 1308
# 1309
# 1310
# 1312
# 1313
# 1314
# 1315
# 1316
# 1319
# 1321
# 1323
# 1324
# 1325
# 1326
# 1328
# 1333
# 1336
# 1337
# 1338
# 1339
# 1340
# 1341
# 1342
# 1343
# 1402
# 1408
# 1409
# 1410
# 1413
# 1414
# 1416
# 1417
# 1418
# 1419
# 1423
# 1432
# 1434
# 1435
# 1436
# 1437
# 1438
# 1439
# 1440
# 1441
# 1442
# 1443
# 1444
# 1445
# 1446
# 1447
# 1449
# 1451
# 1452
# 1453
# 1454
# 1455
# 1456
# 1457
# 1459
# 1460
# 1463
# 1464
# 1465
# 1466
# 1467
# 1468
# 1470
# 1471
# 1472
# 1473
# 1474
# 1475
# 1476
# 1477
# 1480
# 1489
# 1503
# 1504
# 1506
# 1507
# 1512
# 1513
# 1514
# 1515
# 1516
# 1517
# 1519
# 1521
# 1522
# 1524
# 1525
# 1526
# 1527
# 1528
# 1529
# ...

# %%
rollingData=st.stockRolling(typeData,'1101')
rollingData
# Out:
# date
# 2017-09-30             NaN
# 2017-12-31             NaN
# 2018-03-31             NaN
# 2018-06-30    1.099182e+11
# 2018-09-30    1.190170e+11
# 2018-12-31    1.245945e+11
# 2019-03-31    1.257716e+11
# 2019-06-30    1.238178e+11
# 2019-09-30    1.224991e+11
# 2019-12-31    1.227830e+11
# 2020-03-31    1.194029e+11
# 2020-06-30    1.184993e+11
# 2020-09-30    1.174696e+11
# 2020-12-31    1.143672e+11
# 2021-03-31    1.144287e+11
# 2021-06-30    1.119508e+11
# 2021-09-30    1.090236e+11
# 2021-12-31    1.070415e+11
# 2022-03-31    1.079773e+11
# 2022-06-30    1.051694e+11
# Name: 1101, dtype: float64

# %%
increaseData=st.rollingIncrease(rollingData)
increaseData
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#              increase  index
# date
# 2018-09-30  20.238095   True
# 2018-12-31   8.168317   True
# 2019-03-31   1.830664   True
# 2019-06-30  -0.674157  False
# 2019-09-30  -3.619910  False
# 2019-12-31   3.990610   True
# 2020-03-31  -4.966140  False
# 2020-06-30  -0.712589  False
# 2020-09-30   3.827751   True
# 2020-12-31  -0.460829  False
# 2021-03-31   0.462963   True
# 2021-06-30  -3.225806  False
# 2021-09-30 -14.761905  False
# 2021-12-31  -7.821229  False
# 2022-03-31 -11.212121  False
# 2022-06-30 -44.027304  False

# %%
increasePeriodData=st.increasePeriodData(increaseData)
increasePeriodData
# Out:
# {'increasePeriod': [3, 1, 1, 1],
#  'decreasePeriod': [2, 2, 1, 5],
#  'endPeriod': -5}

# %%
st.periodAnalysis('Revenue').sort_values(by='growth')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#      stock_id  incPeriodMean  decPeriodMean  incPeriodMax  decPeriodMax  \
# 1264     6131            1.7            3.5             2             5
# 1438     6497            0.0            1.0             0             1
# 96       1465            3.0           10.0             5            10
# 500      2718            2.7            4.0             4             7
# 723      3349            0.0            1.0             0             1
# ...       ...            ...            ...           ...           ...
# 1290     6165            8.0            8.0             8             8
# ...
