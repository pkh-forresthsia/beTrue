# %%
from dayData import *

localValue=LocalValue()

# %%
# localValue.localPeriodDetail(20)

# %%
# localValue.periodDetailToSQL()
localValue.periodDetailFromSQL()
# Out:
#           index  stockPrice localValue  dayDiffer  increase%
# 0    1999-07-03     8710.71   localMax        148         61
# 1    1999-08-07     6771.75   localMin         35        -22
# 2    1999-09-02     8414.60   localMax         26         24
# 3    1999-11-08     7261.31   localMin         67        -14
# 4    2000-02-18    10393.60   localMax        102         43
# 5    2000-03-16     8250.46   localMin         27        -21
# 6    2000-04-06    10329.00   localMax         21         25
# 7    2000-05-11     8281.68   localMin         35        -20
# 8    2000-06-08     9209.48   localMax         28         11
# 9    2000-10-19     5074.44   localMin        133        -45
# 10   2000-11-08     6164.62   localMax         20         21
# 11   2000-12-28     4555.91   localMin         50        -26
# 12   2001-02-16     6198.22   localMax         50         36
# 13   2001-03-02     5471.62   localMin         14        -12
# ...
