# %%
from monthData import *

monthData=MonthData()
dataTrans=DataTrans()

# %%
# pd.set_option('display.max_columns',None)
# pd.set_option('display.max_rows',None)

# %%
revenue=monthData.revenueData()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13220\2830758374.py in <module>
# ----> 1 revenue=monthData.revenueData()
#
# D:\Jesse\beTrue\main\monthData.py in revenueData(self)
#       7     def revenueData(self):
#       8         revenueData=self.revenue
# ----> 9         revenueData['date']=revenueData['revenue_year']+"-"+revenueData['revenue_month']+"-10"
#      10         return revenueData
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __add__(self, other)
#      98     @unpack_zerodim_and_defer("__add__")
#      99     def __add__(self, other):
# ...

# %%
revenue
# Out:
#               date stock_id country     revenue  revenue_month  revenue_year  \
# 0       2006-01-01     1101  Taiwan  2771490000             12          2005
# 1       2006-01-01     1102  Taiwan  1022776000             12          2005
# 2       2006-01-01     1103  Taiwan   283649000             12          2005
# 3       2006-01-01     1104  Taiwan   345562000             12          2005
# 4       2006-01-01     1107  Taiwan    12381000             12          2005
# ...            ...      ...     ...         ...            ...           ...
# 315631  2022-12-01     9951  Taiwan   500111000             11          2022
# 315632  2022-12-01     9955  Taiwan    91270000             11          2022
# 315633  2022-12-01     9958  Taiwan   944060000             11          2022
# 315634  2022-12-01     9960  Taiwan    96570000             11          2022
# 315635  2022-12-01     9962  Taiwan   308663000             11          2022
#
#          dateStamp
# 0       1136044800
# ...

# %%
revenueData=revenue.reindex(index=dateList)

# %%
revenueData
# Out:
# stock_id    1101  1102  1103  1104  1107  1108  1109  1110  1201  1203  ...  \
# date                                                                    ...
# 2005-12-10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2006-01-10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2006-02-10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2006-03-10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2006-04-10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 2022-07-10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2022-08-10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2022-09-10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2022-10-10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
priod3Increase=dataTrans.nPeriodIncrease(12,revenue,3)
priod3Increase
# Out:
# stock_id    1101  1102  1103  1104  1107  1108  1109  1110  1201  1203  ...  \
# date                                                                    ...
# 2006-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2006-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2006-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2006-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2006-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 2022-08-01   1.0  12.0  -6.0  18.0   NaN  -0.0  12.0 -40.0   3.0   7.0  ...
# 2022-09-01  16.0  10.0   3.0  32.0   NaN  19.0   3.0 -20.0   4.0   4.0  ...
# 2022-10-01  16.0   2.0   1.0  23.0   NaN  28.0  14.0  15.0   4.0   3.0  ...
# 2022-11-01  15.0 -11.0   7.0  21.0   NaN  43.0   1.0  33.0   2.0   8.0  ...
# ...

# %%
priod3Increase1=priod3Increase.reset_index

# %%
priod3Increase1
# Out:
# <bound method DataFrame.reset_index of stock_id    1101  1102  1103  1104  1107  1108  1109  1110  1201  1203  ...  \
# date                                                                    ...
# 2006-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2006-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2006-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2006-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2006-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 2022-08-01   1.0  12.0  -6.0  18.0   NaN  -0.0  12.0 -40.0   3.0   7.0  ...
# 2022-09-01  16.0  10.0   3.0  32.0   NaN  19.0   3.0 -20.0   4.0   4.0  ...
# 2022-10-01  16.0   2.0   1.0  23.0   NaN  28.0  14.0  15.0   4.0   3.0  ...
# 2022-11-01  15.0 -11.0   7.0  21.0   NaN  43.0   1.0  33.0   2.0   8.0  ...
# ...

# %%
dm=DateManage()

# %%
for i in range(len(dateIndex)):
    dateIndex[i]=dm.monthRelease(dateIndex[i])
print(dateIndex)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12228\1665420630.py in <module>
#       1 for i in range(len(dateIndex)):
# ----> 2     dateIndex[i]=dm.monthRelease(dateIndex[i])
#       3 print(dateIndex)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    5033     @final
#    5034     def __setitem__(self, key, value):
# -> 5035         raise TypeError("Index does not support mutable operations")
#    5036
#    5037     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations
