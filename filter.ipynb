# %%
from monthData import *

md=MonthData()

# %%
from seasonData import *

sd=StatementData()

# %%
from dayData import *

# %%
cond1=(md.nMonthYearIncrease(3)>md.nMonthYearIncrease(9)).iloc[-1]

# %%
incomeAfterTax=sd.typeData('IncomeAfterTax')

# %%
cond2=((sd.dt.nPeriodIncrease(4,incomeAfterTax,4)>25).iloc[-1]&((sd.dt.nPeriodIncrease(4,incomeAfterTax,4)>25).iloc[-5])&((sd.dt.nPeriodIncrease(4,incomeAfterTax,4)>25).iloc[-9]))

# %%
incomeAfterTax
# Out:
# stock_id    000018  000019  000020  000022  000024  000025  000026  000027  \
# date
# 2006-03-31     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2006-06-30     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2006-09-30     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2006-12-31     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-03-31     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2021-09-30     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2021-12-31     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-03-31     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-30     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-09-30     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...
