# %%
from priceModel import *
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
sm=StatementModel("2022-11-24",2)

# %%
latestAnalysis1=sm.latestAnalysis()
# Out:
# D:\Jesse\beTrue\main\statement.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summaryData['index'].iloc[i]=summaryData['increase'].iloc[i]>0

# %%
ids=InfoId()
Ids=ids.getId().sort_values(by="stock_id")
pd.merge(latestAnalysis1,Ids,how="inner").sort_values(['估價差距%'],ascending=False)
# Out:
#      stock_id    close     EPS    季成長     年成長  樂觀估計  悲觀估計   估價差距% stock_name  \
# 1614     8421    15.65    8.18     48    1099   215   215  1274.0         旭源
# 534      2915    66.80   27.40    108     187   719   719   976.0        潤泰全
# 491      2702    21.75   18.60      1    6099   488   226   939.0         華園
# 470      2609    64.60   63.50     -3      71  1666   664   928.0         陽明
# 465      2603   161.00   84.18      2      97  2209  1067   563.0         長榮
# 901      4304     8.04    3.82      4     156   100    53   559.0         勝昱
# 489      2643    70.00   17.43     15      98   457   375   436.0         捷迅
# 1155     5519    22.20    4.50     65     115   118   118   432.0         隆大
# 1131     5464    25.45    5.08     97    2123   133   133   423.0         霖宏
# 1164     5533    17.70    5.77      7      79   151    91   414.0         皇鼎
# 105      1475    63.60   12.47     19     399   327   311   389.0         業旺
# ...

# %%
latestAnalysis2=sm.estimateDiscoount(latestAnalysis1).sort_values(['估價差距%'],ascending=False)
# Out:
# stock_id     1104
# close       21.55
# EPS          2.75
# 季成長            26
# 年成長            62
# 樂觀估計          275
# 悲觀估計           91
# 估價差距%       322.0
# 成長估計%          -9
# Name: 3, dtype: object
# stock_id     1108
# close       10.55
# EPS          0.98
# 季成長            33
# 年成長            70
# 樂觀估計           98
# 悲觀估計           41
# 估價差距%       289.0
# 成長估計%          -2
# Name: 4, dtype: object
# stock_id     1203
# close        34.2
# EPS          2.62
# 季成長            40
# 年成長            25
# 樂觀估計          140
# 悲觀估計           84
# 估價差距%       146.0
# 成長估計%           3
# Name: 8, dtype: object
# stock_id    1234
# close       33.0
# EPS         2.37
# 季成長           18
# 年成長           35
# 樂觀估計         106
# 悲觀估計          58
# 估價差距%       76.0
# 成長估計%          4
# Name: 23, dtype: object
# stock_id     1259
# close        72.8
# EPS           5.1
# 季成長            49
# 年成長           142
# 樂觀估計          510
# 悲觀估計          363
# 估價差距%       399.0
# 成長估計%           5
# ...

# %%
latestAnalysis2
# Out:
#      stock_id    close     EPS    季成長    年成長  樂觀估計  悲觀估計   估價差距% 成長估計%
# 1068     5212     0.00    2.89     10      0    52    34     inf     0
# 1295     6210     0.00    1.86    -22    -40     8     3     inf     0
# 1514     7556     0.00    5.72      7     37   273    91     inf     0
# 1498     6752     0.00    5.98      6     42   337    91     inf     0
# 999      4767     0.00    2.65      6     -1    40    30     inf     0
# 1457     6629     0.00    5.93     14     -1   123    67     inf     0
# 1660     8921     0.00    0.64    -14     41    35     4     inf     0
# 242      2025     4.83    2.75     46    398   275   181  3647.0   -40
# 1304     6220    27.05    8.92   1065    671   892   892  3198.0   -29
# 1588     8234    30.50    6.57    143    481   657   657  2054.0   -20
# 1162     5519    22.20    4.50     64    100   450   450  1927.0   -19
# 623      3090    52.30    8.42     59     89   842   835  1497.0   -14
# ...
