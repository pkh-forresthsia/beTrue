# %% [markdown]
# 用最近4季的稅後淨利年增率 當成年增率
# 用最近4季的EPS當成第一年 成長5年 後來都當作持平
# 取最新的股價 看這個報酬率是多少折現回來的

# %%
from statement import *
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
# 用最近4季的稅後淨利年增率 當成年增率
sm=StatementManage("2022-11-22",2)
typeData=sm.getType("EPS")

# %%
# sm.nYearDataFromSql

# %%
typeData
# Out:
# stock_id    000104  000116  000218  000511  000532  000538  000546  000560  \
# date
# 2020-09-30     NaN    0.66     NaN     NaN     NaN    0.44     NaN     NaN
# 2020-12-31    1.10    0.38    0.54   -0.13    1.22    0.52   -0.03    1.02
# 2021-03-31     NaN    0.56     NaN     NaN     NaN    0.60     NaN     NaN
# 2021-06-30    2.01    0.73    0.41    0.64    1.78    0.82    0.00    1.27
# 2021-09-30     NaN    1.12     NaN     NaN     NaN    0.52     NaN     NaN
# 2021-12-31    0.93    0.65    0.00   -0.08    1.86    0.49    0.23    1.17
# 2022-03-31     NaN    0.40     NaN     NaN     NaN    0.20     NaN     NaN
# 2022-06-30    0.18    0.44   -0.55   -0.39    1.01    0.09    0.07    0.46
#
# stock_id    000601  000616  000638  000646  000695  000700  000708  000775  \
# date
# 2020-09-30     NaN    0.45     NaN     NaN     NaN    0.39     NaN     NaN
# 2020-12-31    0.78    0.52    0.80    1.04    0.66    0.33    0.02    0.46
# ...

# %%
rollingData=sm.stockRolling(typeData,"2330")
rollingData
# Out:
# date
# 2020-09-30      NaN
# 2020-12-31      NaN
# 2021-03-31      NaN
# 2021-06-30    21.37
# 2021-09-30    22.09
# 2021-12-31    23.01
# 2022-03-31    25.44
# 2022-06-30    29.40
# Name: 2330, dtype: float64

# %%
rollingIncreaseData=sm.rollingIncrease(rollingData,4)
rollingIncreaseData
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#              increase index
# date
# 2022-06-30  37.576041  True

# %%
rollingIncreaseData.iloc[-1].increase
# Out:
# 37.57604117922322

# %%
increaseData=sm.priceModel("EPS")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
increaseData
# Out:
#      stock_id           increaseEPS
# 0        1101                   -61
# 1        1102                   -20
# 2        1103                   -70
# 3        1104                     9
# 4        1108                     0
# 5        1109                   -57
# 6        1110                   -20
# 7        1201                   -17
# 8        1203                   -20
# 9        1210                   -45
# 10       1213                    70
# 11       1215                   -20
# 12       1216                   -15
# 13       1217                   -84
# 14       1218                   -29
# 15       1219                   -32
# 16       1220                   -55
# 17       1225                    -6
# 18       1227                   -48
# 19       1229                   -24
# 20       1231                   -11
# 21       1232                   -13
# 22       1233                    38
# 23       1234                   -11
# 24       1235                   274
# ...
