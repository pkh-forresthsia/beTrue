# %%
from priceModel import *
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
sm=StatementModel("2022-11-24",2)

# %%
# sm.nYearDataFromSql

# %%
latestAnalysis1=sm.latestAnalysis()
# Out:
# D:\Jesse\beTrue\main\statement.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summaryData['index'].iloc[i]=summaryData['increase'].iloc[i]>0

# %%
latestAnalysis1
# Out:
#      stock_id    close     EPS    季成長    年成長  樂觀估計  悲觀估計
# 0        1101    33.20    1.27    -29    -72     4     0
# 1        1102    41.10    4.64      5    -12    66    32
# 2        1103    17.45   -0.24   -127   -107     0     0
# 3        1104    21.55    2.75     26     62   275    91
# 4        1108    10.55    0.98     33     70    98    41
# 5        1109    15.55    1.74     16    -41    40     3
# 6        1110    17.85    0.11    -41    -74     0     0
# 7        1201    19.25    0.89    -12    -25     6     3
# 8        1203    34.20    2.62     40     25   140    84
# 9        1210    43.55    2.36     17     -3    56    24
# 10       1213     7.05   -1.38    -23    -17     0     0
# 11       1215    78.40    5.13      7     -1    82    58
# 12       1216    65.30    3.17      1     -3    39    32
# 13       1217    10.30    0.45    264    -14    45     3
# 14       1218    40.80    1.19      3     -3    16    12
# ...

# %%
typeData=sm.getType("EPS")
typeData
# Out:
# stock_id    000104  000116  000218  000511  000532  000538  000546  000560  \
# date
# 2020-12-31    1.10    0.38    0.54   -0.13    1.22    0.52   -0.03    1.02
# 2021-03-31     NaN    0.56     NaN     NaN     NaN    0.60     NaN     NaN
# 2021-06-30    2.01    0.73    0.41    0.64    1.78    0.82    0.00    1.27
# 2021-09-30     NaN    1.12     NaN     NaN     NaN    0.52     NaN     NaN
# 2021-12-31    0.93    0.65    0.00   -0.08    1.86    0.49    0.23    1.17
# 2022-03-31     NaN    0.40     NaN     NaN     NaN    0.20     NaN     NaN
# 2022-06-30    0.18    0.44   -0.55   -0.39    1.01    0.09    0.07    0.46
# 2022-09-30     NaN    0.60     NaN     NaN     NaN    0.37     NaN     NaN
#
# stock_id    000601  000616  000638  000646  000695  000700  000708  000775  \
# date
# 2020-12-31    0.78    0.52    0.80    1.04    0.66    0.33    0.02    0.46
# 2021-03-31     NaN    0.54     NaN     NaN     NaN    0.50     NaN     NaN
# ...

# %%
rollingData=sm.stockRolling(typeData,"1109")
rollingData
# Out:
# date
# 2020-12-31     NaN
# 2021-03-31     NaN
# 2021-06-30     NaN
# 2021-09-30    2.83
# 2021-12-31    2.52
# 2022-03-31    1.95
# 2022-06-30    1.42
# 2022-09-30    1.74
# Name: 1109, dtype: float64

# %%
rollingData[-1]
# Out:
# 1.27

# %%
rollingIncreaseData=sm.rollingIncrease(rollingData,4)
rollingIncreaseData
# Out:
# D:\Jesse\beTrue\main\statement.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summaryData['index'].iloc[i]=summaryData['increase'].iloc[i]>0
#              increase index
# date
# 2022-09-30  54.866455  True

# %%
rollingIncreaseData['increase'].iloc[-1]
# Out:
# 16.36054421768709

# %%
rollingIncreaseData2=sm.rollingIncrease(rollingData,1)
rollingIncreaseData2
# Out:
# D:\Jesse\beTrue\main\statement.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summaryData['index'].iloc[i]=summaryData['increase'].iloc[i]>0
#              increase index
# date
# 2021-09-30   3.369209  True
# 2021-12-31   4.164780  True
# 2022-03-31  10.560626  True
# 2022-06-30  15.566038  True

# %%
rollingIncreaseData.iloc[-1].increase
# Out:
# 37.57604117922322

# %%
increaseData=sm.priceModel("EPS")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
increaseData
# Out:
#      stock_id           increaseEPS
# 0        1101                   -61
# 1        1102                   -20
# 2        1103                   -70
# 3        1104                     9
# 4        1108                     0
# 5        1109                   -57
# 6        1110                   -20
# 7        1201                   -17
# 8        1203                   -20
# 9        1210                   -45
# 10       1213                    70
# 11       1215                   -20
# 12       1216                   -15
# 13       1217                   -84
# 14       1218                   -29
# 15       1219                   -32
# 16       1220                   -55
# 17       1225                    -6
# 18       1227                   -48
# 19       1229                   -24
# 20       1231                   -11
# 21       1232                   -13
# 22       1233                    38
# 23       1234                   -11
# 24       1235                   274
# ...
