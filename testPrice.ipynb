# %%
from price import *

# %%
allPrice=DayInfoAll()

# %%
price=allPrice.getAllPriceData("2022-11-24")
price
# Out:
#              date               stock_id  Trading_Volume  Trading_money  \
# 0      2022-11-24                   0050        15641447     1817903787
# 1      2022-11-24                   0051           16930         879790
# 2      2022-11-24                   0052          416952       41611439
# 3      2022-11-24                   0053            3231         178382
# 4      2022-11-24                   0055          377106        8147893
# ...           ...                    ...             ...            ...
# 32551  2022-11-24                  TAIEX      5601547331   221042345269
# 32552  2022-11-24                   TPEx       711493168    66023331838
# 32553  2022-11-24               Textiles        26813895     1171323533
# 32554  2022-11-24                Tourism         4731096      591493120
# 32555  2022-11-24  TradingConsumersGoods        15723079     1234941936
#
#            open       max       min     close  spread  Trading_turnover
# ...

# %%
singlePrice=DayInfo()

# %%
stockPrice=singlePrice.getPriceData("1999-01-01","2022-11-24","2330")
stockPrice
# Out:
#             date stock_id  Trading_Volume  Trading_money   open    max    min  \
# 0     1999-01-05     2330        17733000     1222948000   71.0   71.0   68.0
# 1     1999-01-06     2330        21492123     1493826134   68.0   71.0   68.0
# 2     1999-01-07     2330        45711016     3372616234   74.0   75.0   71.5
# 3     1999-01-08     2330        72618091     5606699997   76.5   78.5   75.5
# 4     1999-01-11     2330        92199427     7395340432   80.0   81.0   79.0
# ...          ...      ...             ...            ...    ...    ...    ...
# 5939  2022-11-18     2330        37001332    18131673834  491.5  494.0  486.0
# 5940  2022-11-21     2330        30609465    14843805078  487.5  489.5  480.5
# 5941  2022-11-22     2330        39329440    19112616916  476.0  491.0  476.0
# 5942  2022-11-23     2330        34752559    17111333375  494.5  496.0  488.5
# 5943  2022-11-24     2330        28477359    14073196704  494.0  496.0  492.0
#
# ...
