# %%
from dayData import *

dayData=DayData()

# %%
dm=DateManage()

# %%
close=dayData.price.pivot_table(index='date',columns='stock_id',values='close')
close
# Out:
# stock_id      0050   0051   0052   0053   0055   0056   0057   0061  006201  \
# date
# 1999-01-05     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 1999-01-06     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 1999-01-07     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 1999-01-08     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 1999-01-11     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# ...            ...    ...    ...    ...    ...    ...    ...    ...     ...
# 2022-12-08  113.25  52.50  96.70  54.30  21.76  25.29  80.95  18.74   15.91
# 2022-12-09  115.00  52.55  98.30  55.05  21.88  25.51  81.90  18.82   15.97
# 2022-12-12  113.90  52.30  97.15  54.45  21.76  25.50  81.20  18.68   15.82
# 2022-12-13  113.40  52.30  96.70  54.10  21.75  25.53  80.70  18.65   15.70
# 2022-12-14  114.80  53.00  98.15  54.90  21.90  25.68  81.75  18.73   16.01
#
# ...

# %%
priceIncrease=close.loc['2022-12-14']/close.loc['2006-01-11']-1

# %%
priceIncrease[priceIncrease.notna()].sort_values()
# Out:
# stock_id
# 4419    -1.000000
# 3115    -1.000000
# 6221    -1.000000
# 5205    -1.000000
# 3067    -1.000000
#           ...
# 3004    36.250000
# 9906    39.180180
# 5306    40.232877
# 9931          inf
# 2539          inf
# Length: 954, dtype: float64
