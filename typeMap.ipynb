# %%
from data import *

fromSQL=FromSQL()

# %%
FinancialStatements=fromSQL.typeMap('TaiwanStockFinancialStatements')
FinancialStatements
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
BalanceSheet=fromSQL.typeMap('TaiwanStockBalanceSheet')
BalanceSheet
# Out:
#                                                                                 stock_id
# type                                               origin_name
# AccountsPayable                                    應付帳款                              inf
# AccountsPayableToRelatedParties                    應付帳款－關係人                          inf
# AccountsPayableToRelatedParties_per                應付帳款－關係人                          inf
# AccountsPayable_per                                應付帳款                              inf
# AccountsReceivableDuefromRelatedPartiesNet         應收帳款－關係人淨額                        inf
# AccountsReceivableDuefromRelatedPartiesNet_per     應收帳款－關係人淨額                        inf
# AccountsReceivableNet                              應收帳款淨額                            inf
# AccountsReceivableNet_per                          應收帳款淨額                            inf
# BillsReceivableNet                                 應收票據淨額                            inf
# ...

# %%
CashFlowsStatement=fromSQL.typeMap('TaiwanStockCashFlowsStatement')
CashFlowsStatement
# Out:
#                                                                 stock_id
# type                                          origin_name
# AccountsPayable                               應付帳款增加(減少)             inf
# AmortizationExpense                           攤銷費用                   inf
# AmountDueToRelatedParties                     應付帳款-關係人增加(減少)         inf
# CashBalancesBeginningOfPeriod                 期初現金及約當現金餘額            inf
# CashBalancesEndOfPeriod                       期末現金及約當現金餘額            inf
# CashBalancesIncrease                          本期現金及約當現金增加（減少）數       inf
# CashFlowsFromOperatingActivities              營業活動之淨現金流入(流出)         inf
#                                               營業活動之淨現金流入（流出）         inf
# CashFlowsProvidedFromFinancingActivities      籌資活動之淨現金流入（流出）         inf
# CashProvidedByInvestingActivities             投資活動之淨現金流入(流出)         inf
#                                               投資活動之淨現金流入（流出）         inf
# ...
