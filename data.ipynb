# %%
from data import *

update=Update()
fromSQL=FromSQL()
# fromType=FromType()

# %%
# update.downloadAll()
# update.updateAll()
update.singleStockToSQL("TAIEX",'2006-01-01','2022-11-30','TaiwanStockPrice')
# Out:
# get single data:  TAIEX 2006-01-01 2022-11-30 TaiwanStockPrice
# update data TAIEX 2006-01-01 2022-11-30 TaiwanStockPrice

# %%
fromSQL.allTypeFromSQL()
# Out:
# {'TaiwanStockMonthRevenue': ['revenue'],
#  'TaiwanStockPrice': ['Trading_Volume',
#   'Trading_money',
#   'open',
#   'max',
#   'min',
#   'close',
#   'spread',
#   'Trading_turnover'],
#  'TaiwanStockFinancialStatements': ['OperatingExpenses',
#   'IncomeLossFromDiscontinuedOperation',
#   'ExtraordinaryItems',
#   'CumulativeEffectOfChangesInAccountingPrinciple',
#   'EPS',
#   'OperatingIncome',
#   'PreTaxIncome',
#   'TAX',
#   'TotalConsolidatedProfitForThePeriod',
#   'Revenue',
#   'CostOfGoodsSold',
#   'GrossProfit',
#   'UnrealizedGainFromInterAffiliateAccounts',
#   'RealizedGainFromInterAffiliateAccounts',
#   'TotalNonbusinessIncome',
#   'TotalnonbusinessExpenditure',
#   'IncomeBeforeTaxFromContinuingOperations',
#   'IncomeFromContinuingOperations',
#   '-',
#   'NetIncome',
#   'NetInterestIncome',
#   'ServiceFeeRevenueCommissionNet',
#   'NetNonInterestIncome',
#   'BadDebts',
#   'IncomeAfterTaxFromContinuingOperations',
# ...

# %%
fromType.data("close")
# Out:
# stock_id      0050   0051   0052   0053   0055   0056   0057   0061  006201  \
# date
# 2006-01-02     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 2006-01-03     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 2006-01-04     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 2006-01-05     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 2006-01-06     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# ...            ...    ...    ...    ...    ...    ...    ...    ...     ...
# 2022-12-08  113.25  52.50  96.70  54.30  21.76  25.29  80.95  18.74   15.91
# 2022-12-09  115.00  52.55  98.30  55.05  21.88  25.51  81.90  18.82   15.97
# 2022-12-12  113.90  52.30  97.15  54.45  21.76  25.50  81.20  18.68   15.82
# 2022-12-13  113.40  52.30  96.70  54.10  21.75  25.53  80.70  18.65   15.70
# 2022-12-14  114.80  53.00  98.15  54.90  21.90  25.68  81.75  18.73   16.01
#
# ...

# %%
fromSQL.datasetFromSQL('TaiwanStockFinancialStatements')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# OperationalError: no such table: close
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28512/2375466587.py in <module>
# ----> 1 fromSQL.datasetFromSQL('close')
#
# ~\Desktop\Jesse\beTrue\main\data.py in datasetFromSQL(self, dataset)
#     155         conn=sqlite3.connect(connstr)
#     156         s="""select * from '%s' """%(dataset)
# --> 157         data=pd.read_sql(s,conn)
#     158         return data
#     159     def typeDataFromSQL(self,type,dataset):
#
# ...
