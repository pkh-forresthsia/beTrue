# %%
from data import *

update=Update()

# %%
update.updateSinglePriceData()
# Out:
# get single data:  1435 2006-01-01 2022-11-30 TaiwanStockPrice
# update data 1435 2006-01-01 2022-11-30 TaiwanStockPrice
# get single data:  2477 2006-01-01 2022-11-30 TaiwanStockPrice
# update data 2477 2006-01-01 2022-11-30 TaiwanStockPrice
# get single data:  3018 2006-01-01 2022-11-30 TaiwanStockPrice
# update data 3018 2006-01-01 2022-11-30 TaiwanStockPrice
# get single data:  3642 2006-01-01 2022-11-30 TaiwanStockPrice
# update data 3642 2006-01-01 2022-11-30 TaiwanStockPrice
# get single data:  4414 2006-01-01 2022-11-30 TaiwanStockPrice
# update data 4414 2006-01-01 2022-11-30 TaiwanStockPrice
# get single data:  5314 2006-01-01 2022-11-30 TaiwanStockPrice
# update data 5314 2006-01-01 2022-11-30 TaiwanStockPrice
# get single data:  6201 2006-01-01 2022-11-30 TaiwanStockPrice
# update data 6201 2006-01-01 2022-11-30 TaiwanStockPrice
# get single data:  6202 2006-01-01 2022-11-30 TaiwanStockPrice
# update data 6202 2006-01-01 2022-11-30 TaiwanStockPrice
# ...

# %%
update.singleStockToSQL("2330","2020-04-02","2020-04-12","TaiwanStockPrice")
# Out:
# get single data:  2330 2020-04-02 2020-04-12 TaiwanStockPrice
# update data 2330 2020-04-02 2020-04-12 TaiwanStockPrice
# C:\Users\user\Desktop\Jesse\beTrue\main\data.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame['dateStamp'][i]=self.dm.getTimeStamp(dataFrame['date'][i])

# %%
update.updateDate()
# Out:
# get single data:  1101 2006-01-01 2022-12-13 TaiwanStockMonthRevenue
# latest data 1101 2006-01-01 2022-12-13 TaiwanStockMonthRevenue
# C:\Users\user\Desktop\Jesse\beTrue\main\data.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame['dateStamp'][i]=self.dm.getTimeStamp(dataFrame['date'][i])
# get single data:  2330 2006-01-01 2022-12-13 TaiwanStockMonthRevenue
# latest data 2330 2006-01-01 2022-12-13 TaiwanStockMonthRevenue
# get single data:  1101 2006-01-01 2022-12-13 TaiwanStockPrice
# latest data 1101 2006-01-01 2022-12-13 TaiwanStockPrice
# get single data:  2330 2006-01-01 2022-12-13 TaiwanStockPrice
# latest data 2330 2006-01-01 2022-12-13 TaiwanStockPrice
# get single data:  1101 2006-01-01 2022-12-13 TaiwanStockFinancialStatements
# ...
