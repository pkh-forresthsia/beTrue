# %%
from data import *

update=Update()
fromSQL=FromSQL()
fromType=FromType()

# %%
# update.downloadAll()
update.updateAll()
# update.singleStockToSQL("TAIEX",'2006-01-01','2022-11-30','TaiwanStockPrice')
# Out:
# get single data:  1101 2006-01-01 2022-12-23 TaiwanStockMonthRevenue
# latest data 1101 2006-01-01 2022-12-23 TaiwanStockMonthRevenue
# get single data:  2330 2006-01-01 2022-12-23 TaiwanStockMonthRevenue
# latest data 2330 2006-01-01 2022-12-23 TaiwanStockMonthRevenue
# get single data:  1101 2006-01-01 2022-12-23 TaiwanStockPrice
# latest data 1101 2006-01-01 2022-12-23 TaiwanStockPrice
# get single data:  2330 2006-01-01 2022-12-23 TaiwanStockPrice
# latest data 2330 2006-01-01 2022-12-23 TaiwanStockPrice
# get single data:  1101 2006-01-01 2022-12-23 TaiwanStockFinancialStatements
# latest data 1101 2006-01-01 2022-12-23 TaiwanStockFinancialStatements
# get single data:  2330 2006-01-01 2022-12-23 TaiwanStockFinancialStatements
# latest data 2330 2006-01-01 2022-12-23 TaiwanStockFinancialStatements
# get single data:  1101 2006-01-01 2022-12-23 TaiwanStockBalanceSheet
# latest data 1101 2006-01-01 2022-12-23 TaiwanStockBalanceSheet
# get single data:  2330 2006-01-01 2022-12-23 TaiwanStockBalanceSheet
# latest data 2330 2006-01-01 2022-12-23 TaiwanStockBalanceSheet
# get single data:  1101 2006-01-01 2022-12-23 TaiwanStockCashFlowsStatement
# latest data 1101 2006-01-01 2022-12-23 TaiwanStockCashFlowsStatement
# get single data:  2330 2006-01-01 2022-12-23 TaiwanStockCashFlowsStatement
# latest data 2330 2006-01-01 2022-12-23 TaiwanStockCashFlowsStatement
# get multi data:  2022-12-01 TaiwanStockMonthRevenue
# latest data 2022-12-01 TaiwanStockMonthRevenue
# get multi data:  2022-12-20 TaiwanStockPrice
# update data 2022-12-20 TaiwanStockPrice
# get multi data:  2022-12-21 TaiwanStockPrice
# update data 2022-12-21 TaiwanStockPrice
# get multi data:  2022-12-22 TaiwanStockPrice
# update data 2022-12-22 TaiwanStockPrice

# %%
fromSQL.allTypeFromSQL()
# Out:
# {'TaiwanStockMonthRevenue': ['revenue'],
#  'TaiwanStockPrice': ['Trading_Volume',
#   'Trading_money',
#   'open',
#   'max',
#   'min',
#   'close',
#   'spread',
#   'Trading_turnover'],
#  'TaiwanStockFinancialStatements': ['OperatingExpenses',
#   'IncomeLossFromDiscontinuedOperation',
#   'ExtraordinaryItems',
#   'CumulativeEffectOfChangesInAccountingPrinciple',
#   'EPS',
#   'OperatingIncome',
#   'PreTaxIncome',
#   'TAX',
#   'TotalConsolidatedProfitForThePeriod',
#   'Revenue',
#   'CostOfGoodsSold',
#   'GrossProfit',
#   'UnrealizedGainFromInterAffiliateAccounts',
#   'RealizedGainFromInterAffiliateAccounts',
#   'TotalNonbusinessIncome',
#   'TotalnonbusinessExpenditure',
#   'IncomeBeforeTaxFromContinuingOperations',
#   'IncomeFromContinuingOperations',
#   '-',
#   'NetIncome',
#   'NetInterestIncome',
#   'ServiceFeeRevenueCommissionNet',
#   'NetNonInterestIncome',
#   'BadDebts',
#   'IncomeAfterTaxFromContinuingOperations',
#   'IncomeLossAfterTaxFromDiscontinuedOperation',
#   'ExtraordinaryItemsAfterTax',
#   'CumulativeEffectOfChangesInAccountingPrincipleAfterTax',
#   'IncomeAfterTaxes',
#   'AdjustmentItem',
#   'ConsolidatedNetIncome',
#   'TotalConsolidatedProfitForThePeriodBelongsParentCompany',
#   'ConsolidatedNetIncomeAttributed2NoncontrollingInterest',
#   'IncomeBeforeIncomeTax',
#   'OtherComprehensiveIncomeAfterTax',
#   'EquityAttributableToOwnersOfParent',
#   'NoncontrollingInterests',
#   'Income',
#   'Expense',
#   '所得稅利益（費用）',
#   'OtherComprehensiveIncomeAfterTaxThePeriod',
#   'TotalNonoperatingIncomeAndExpense',
#   'OtherComprehensiveIncome',
#   'UnrealizedGain',
#   'RealizedGain',
#   'OTHNOE',
#   'BadDebtExpenseGuaranteeLiabilityProvisions',
#   'TotalConsolidatedProfitForThePeriodAfterTax',
#   '呆帳費用及保證責任準備提存（各項提存）',
#   'IncomeAfterTax',
#   'NetChangeInProvisionsForInsuranceLiabilities',
#   'GainsOnInitialRecognitionOfBiologicalAssetsForCurrentPeriod',
#   'GainsOnChangesInFairValueLessCosts2SellOfBiologicalAssetsForCurrentPeriod'],
#  'TaiwanStockBalanceSheet': ['AccountsPayable_per',
#   'AccountsPayableToRelatedParties',
#   'AccountsPayableToRelatedParties_per',
#   'AccountsReceivableDuefromRelatedPartiesNet',
#   'AccountsReceivableDuefromRelatedPartiesNet_per',
#   'AccountsReceivableNet_per',
#   'BondsPayable',
#   'BondsPayable_per',
#   'CapitalStock_per',
#   'CapitalSurplus_per',
#   'CashAndCashEquivalents_per',
#   'CurrentAssets_per',
#   'CurrentAvailableForSaleFinancialAssets_per',
#   'CurrentFinancialAssetsAtFairvalueThroughProfitOrLoss_per',
#   'CurrentLiabilities_per',
#   'CurrentTaxLiabilities_per',
#   'Equity_per',
#   'EquityAttributableToOwnersOfParent_per',
#   'EquivalentIssueSharesOfAdvanceReceiptsForOrdinaryShare',
#   'IntangibleAssets_per',
#   'Inventories_per',
#   'InvestmentAccountedForUsingEquityMethod_per',
#   'Liabilities',
#   'Liabilities_per',
#   'LongtermBorrowings_per',
#   'NoncontrollingInterests_per',
#   'NoncurrentAssets_per',
#   'NonCurrentAvailableForSaleFinancialAssets_per',
#   'NoncurrentLiabilities_per',
#   'NumberOfSharesInEntityHeldByEntityAndByItsSubsidiaries',
#   'OrdinaryShare_per',
#   'OtherCurrentAssets_per',
#   'OtherCurrentLiabilities_per',
#   'OtherEquityInterest_per',
#   'OtherNoncurrentAssets_per',
#   'OtherNoncurrentLiabilities',
#   'OtherNoncurrentLiabilities_per',
#   'OtherPayables_per',
#   'OtherReceivablesDueFromRelatedParties_per',
#   'PropertyPlantAndEquipment_per',
#   'RetainedEarnings_per',
#   'ShorttermBorrowings_per',
#   'TotalAssets_per',
#   'CashAndCashEquivalents',
#   'CurrentFinancialAssetsAtFairvalueThroughProfitOrLoss',
#   'BillsReceivableNet',
#   'BillsReceivableNet_per',
#   'Prepayments',
#   'Prepayments_per',
#   'CurrentAvailableForSaleFinancialAssets',
#   'AccountsReceivableNet',
#   'OtherReceivablesDueFromRelatedParties',
#   'Inventories',
#   'OtherCurrentAssets',
#   'CurrentAssets',
#   'InvestmentAccountedForUsingEquityMethod',
#   'PropertyPlantAndEquipment',
#   'IntangibleAssets',
#   'OtherNoncurrentAssets',
#   'NoncurrentAssets',
#   'TotalAssets',
#   'ShorttermBorrowings',
#   'AccountsPayable',
#   'OtherPayables',
#   'CurrentTaxLiabilities',
#   'OtherCurrentLiabilities',
#   'CurrentLiabilities',
#   'LongtermBorrowings',
#   'NoncurrentLiabilities',
#   'OrdinaryShare',
#   'CapitalStock',
#   'CapitalSurplus',
#   'RetainedEarnings',
#   'OtherEquityInterest',
#   'EquityAttributableToOwnersOfParent',
#   'NoncontrollingInterests',
#   'Equity',
#   'NonCurrentAvailableForSaleFinancialAssets',
#   'CurrentFinancialLiabilitiesAtFairValueThroughProfitOrLoss',
#   'CurrentFinancialLiabilitiesAtFairValueThroughProfitOrLoss_per',
#   'CurrentProvisions',
#   'CurrentProvisions_per',
#   'DeferredTaxAssets',
#   'DeferredTaxAssets_per',
#   'LegalReserve_per',
#   'OtherReceivable',
#   'OtherReceivable_per',
#   'UnappropriatedRetainedEarningsAaccumulatedDeficit',
#   'UnappropriatedRetainedEarningsAaccumulatedDeficit_per',
#   'LegalReserve',
#   'CapitalSurplusAdditionalPaidInCapital',
#   'CapitalSurplusAdditionalPaidInCapital_per',
#   'ConstructionContractReceivable',
#   'ConstructionContractReceivable_per',
#   'CurrentDerivativeFinancialLiabilitiesForHedging',
#   'CurrentDerivativeFinancialLiabilitiesForHedging_per',
#   'CurrentHeldToMaturityFinancialAssets',
#   'CurrentHeldToMaturityFinancialAssets_per',
#   'FinancialAssetsAtFairvalueThroughOtherComprehensiveIncome',
#   'FinancialAssetsAtFairvalueThroughOtherComprehensiveIncome_per',
#   'CapitalSurplusChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod',
#   'CapitalSurplusChangesInEquityOfAssociatesAndJointVenturesAccountedForUsingEquityMethod_per',
#   'CapitalSurplusChangesInOwnershipInterestsInSubsidiaries',
#   'CapitalSurplusChangesInOwnershipInterestsInSubsidiaries_per',
#   'CapitalSurplusDonatedAssetsReceived',
#   'CapitalSurplusDonatedAssetsReceived_per',
#   'CapitalSurplusNetAssetsFromMerger_per',
#   'CapitalSurplusNetAssetsFromMerger',
#   'TotalLiabilitiesEquity_per',
#   'TotalLiabilitiesEquity',
#   'CurrentIncomeTaxAssets',
#   'CurrentIncomeTaxAssets_per',
#   'HedgingAinancialAssets',
#   'HedgingAinancialAssets_per',
#   'FinancialAssetsAtAmortizedCost',
#   'FinancialAssetsAtAmortizedCost_per'],
#  'TaiwanStockCashFlowsStatement': ['TotalIncomeLossItems',
#   'CashFlowsProvidedFromFinancingActivities',
#   'DecreaseInShortTermLoans',
#   'OtherNonCurrentLiabilitiesDecrease',
#   'InterestIncome',
#   'CashReceivedThroughOperations',
#   'PayTheInterest',
#   'InventoryIncrease',
#   'CashBalancesIncrease',
#   'ReceivableIncrease',
#   'CashBalancesBeginningOfPeriod',
#   'RepaymentOfLongTermDebt',
#   'AmountDueToRelatedParties',
#   'InterestExpense',
#   'AccountsPayable',
#   'IncomeBeforeIncomeTaxFromContinuingOperations',
#   'PropertyAndPlantAndEquipment',
#   'NetIncomeBeforeTax',
#   'CashFlowsFromOperatingActivities',
#   'CashProvidedByInvestingActivities',
#   'CashBalancesEndOfPeriod',
#   'OtherNonCurrentLiabilitiesIncrease',
#   'Depreciation',
#   'AmortizationExpense',
#   'ProceedsFromLongTermDebt',
#   'RedemptionOfBonds',
#   'UnrealizedGain',
#   'DecreaseInDepositDeposit',
#   'RealizedGain',
#   'HedgingFinancialLiabilities',
#   'RentalPrincipalRepayments']}

# %%
fromType.data("revenue")
# Out:
# stock_id            1101          1102         1103         1104        1107  \
# date
# 2006-01-01  2.771490e+09  1.022776e+09  283649000.0  345562000.0  12381000.0
# 2006-02-01  2.366663e+09  9.505260e+08  267920000.0  298757000.0   7210000.0
# 2006-03-01  1.797171e+09  7.747080e+08  181348000.0  233775000.0   6259000.0
# 2006-04-01  2.199454e+09  9.662290e+08  216946000.0  305273000.0   6612000.0
# 2006-05-01  2.118570e+09  8.473590e+08  217074000.0  266557000.0   6195000.0
# ...                  ...           ...          ...          ...         ...
# 2022-08-01  1.010247e+10  7.864622e+09  178825000.0  580420000.0         NaN
# 2022-09-01  1.068986e+10  7.069221e+09  182371000.0  605512000.0         NaN
# 2022-10-01  1.040490e+10  6.994078e+09  205264000.0  597159000.0         NaN
# 2022-11-01  1.136810e+10  7.601097e+09  209429000.0  634981000.0         NaN
# 2022-12-01  9.674576e+09  8.306062e+09  221763000.0  631827000.0         NaN
#
# stock_id           1108         1109         1110          1201         1203  \
# date
# 2006-01-01  427562000.0  202280000.0  190293000.0  7.251140e+08  162761000.0
