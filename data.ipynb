# %%
from data import *

update=Update()

# %%
multiStock=update.multiStock("2020-04-06","TaiwanStockPrice")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16136/2594864396.py in <module>
# ----> 1 multiStock=update.multiStock("2020-04-06","TaiwanStockPrice")
#
# NameError: name 'update' is not defined

# %%
multiStock
# Out:
#              date               stock_id  Trading_Volume  Trading_money  \
# 0      2020-04-06                   0050        12207626      935731083
# 1      2020-04-06                   0051           33000         953030
# 2      2020-04-06                   0052          178700       10660088
# 3      2020-04-06                   0053           17000         589750
# 4      2020-04-06                   0054           10000         200040
# ...           ...                    ...             ...            ...
# 21980  2020-04-06                  TAIEX      5242549478   153193812291
# 21981  2020-04-06                   TPEx       362730556    30877495866
# 21982  2020-04-06               Textiles        36875556     1223480295
# 21983  2020-04-06                Tourism         3779129      263140521
# 21984  2020-04-06  TradingConsumersGoods        17132883     1419497801
#
#           open      max      min    close  spread  Trading_turnover
# ...

# %%
update.addStamp(multiStock)
# Out:
# C:\Users\user\Desktop\Jesse\beTrue\main\data.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame['dateStamp'][i]=self.dm.getTimeStamp(dataFrame['date'][i])
#              date               stock_id  Trading_Volume  Trading_money  \
# 0      2020-04-06                   0050        12207626      935731083
# 1      2020-04-06                   0051           33000         953030
# 2      2020-04-06                   0052          178700       10660088
# 3      2020-04-06                   0053           17000         589750
# 4      2020-04-06                   0054           10000         200040
# ...           ...                    ...             ...            ...
# 21980  2020-04-06                  TAIEX      5242549478   153193812291
# ...

# %%
update.singleStockToSQL("2330","2020-04-02","2020-04-12","TaiwanStockPrice")
# Out:
# get single data:  2330 2020-04-02 2020-04-12 TaiwanStockPrice
# update data 2330 2020-04-02 2020-04-12 TaiwanStockPrice
# C:\Users\user\Desktop\Jesse\beTrue\main\data.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame['dateStamp'][i]=self.dm.getTimeStamp(dataFrame['date'][i])

# %%
update.updateDate()
# Out:
# get single data:  1101 2006-01-01 2022-12-13 TaiwanStockMonthRevenue
# latest data 1101 2006-01-01 2022-12-13 TaiwanStockMonthRevenue
# C:\Users\user\Desktop\Jesse\beTrue\main\data.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame['dateStamp'][i]=self.dm.getTimeStamp(dataFrame['date'][i])
# get single data:  2330 2006-01-01 2022-12-13 TaiwanStockMonthRevenue
# latest data 2330 2006-01-01 2022-12-13 TaiwanStockMonthRevenue
# get single data:  1101 2006-01-01 2022-12-13 TaiwanStockPrice
# latest data 1101 2006-01-01 2022-12-13 TaiwanStockPrice
# get single data:  2330 2006-01-01 2022-12-13 TaiwanStockPrice
# latest data 2330 2006-01-01 2022-12-13 TaiwanStockPrice
# get single data:  1101 2006-01-01 2022-12-13 TaiwanStockFinancialStatements
# ...

# %%
update.latestDate('TaiwanStockMonthRevenue')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# OperationalError: no such table: TaiwanStockMonthRevenue
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26568/181343298.py in <module>
# ----> 1 update.latestDate('TaiwanStockMonthRevenue')
#
# ~\Desktop\Jesse\beTrue\main\data.py in latestDate(self, dataset)
#      78         connstr=self.connstr2+dataset+".db"
#      79         conn=sqlite3.connect(connstr)
# ---> 80         dateList=pd.read_sql("""select date from '%s' order by date"""%(dataset),conn)
#      81         return dateList['date']
# ...

# %%
update.updateId()
# Out:
# get multi data:
# latest data 2022-12-01 TaiwanStockMonthRevenue

# %%
update.latestId()
# Out:
# 0       1101
# 1       1102
# 2       1103
# 3       1104
# 4       1108
#         ...
# 1772    9951
# 1773    9955
# 1774    9958
# 1775    9960
# 1776    9962
# Name: stock_id, Length: 1777, dtype: object
