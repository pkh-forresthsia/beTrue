# %%
from getData import *

read=Read()

# %%
read.getVar()

# %%
read.allVar
# Out:
# {'TaiwanStockMonthRevenue': ['revenue'],
#  'TaiwanStockFinancialStatements': Index(['-', 'BadDebts', 'CostOfGoodsSold', 'EPS',
#         'EquityAttributableToOwnersOfParent', 'Expense',
#         'GainsOnChangesInFairValueLessCosts2SellOfBiologicalAssetsForCurrentPeriod',
#         'GainsOnInitialRecognitionOfBiologicalAssetsForCurrentPeriod',
#         'GrossProfit', 'Income', 'IncomeAfterTax', 'IncomeAfterTaxes',
#         'IncomeBeforeTaxFromContinuingOperations',
#         'IncomeFromContinuingOperations', 'IncomeLossFromDiscontinuedOperation',
#         'NetChangeInProvisionsForInsuranceLiabilities', 'NetInterestIncome',
#         'NetNonInterestIncome', 'NoncontrollingInterests', 'OTHNOE',
#         'OperatingExpenses', 'OperatingIncome', 'OtherComprehensiveIncome',
#         'OtherComprehensiveIncomeAfterTax',
#         'OtherComprehensiveIncomeAfterTaxThePeriod', 'PreTaxIncome',
#         'RealizedGain', 'Revenue', 'TAX', 'TotalConsolidatedProfitForThePeriod',
# ...

# %%
read.typeIndex
# Out:
# [('-', '合併前非屬共同控制股權損益'),
#  ('-', '合併前非屬共同控制股權綜合損益淨額'),
#  ('-', '淨利（淨損）歸屬於共同控制下前手權益'),
#  ('-', '綜合損益總額歸屬於共同控制下前手權益'),
#  ('BadDebts', '呆帳費用、承諾及保證責任準備提存'),
#  ('CostOfGoodsSold', '支出'),
#  ('CostOfGoodsSold', '營業成本'),
#  ('EPS', '基本每股盈餘（元）'),
#  ('EquityAttributableToOwnersOfParent', '淨利（損）歸屬於母公司業主'),
#  ('EquityAttributableToOwnersOfParent', '淨利（淨損）歸屬於母公司業主'),
#  ('EquityAttributableToOwnersOfParent', '綜合損益總額歸屬於母公司業主'),
#  ('Expense', '支出及費用'),
#  ('GainsOnChangesInFairValueLessCosts2SellOfBiologicalAssetsForCurrentPeriod',
#   '生物資產當期公允價值減出售成本之變動利益（損失）'),
#  ('GainsOnInitialRecognitionOfBiologicalAssetsForCurrentPeriod',
#   '原始認列生物資產及農產品之利益（損失）'),
#  ('GrossProfit', '營業毛利（毛損）'),
#  ('GrossProfit', '營業毛利（毛損）淨額'),
#  ('Income', '收益'),
#  ('IncomeAfterTax', '本期稅後淨利（淨損）'),
#  ('IncomeAfterTaxes', '本期淨利（淨損）'),
#  ('IncomeBeforeTaxFromContinuingOperations', '繼續營業單位稅前淨利（淨損）'),
#  ('IncomeFromContinuingOperations', '繼續營業單位本期淨利（淨損）'),
# ...
